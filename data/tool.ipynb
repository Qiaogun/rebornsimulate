# %%
import pandas as pd

# %%
df_Population = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_3731322/API_SP.POP.TOTL_DS2_en_csv_v2_3731322.csv',header=2)
df_Birth_rate = pd.read_csv('API_SP.DYN.CBRT.IN_DS2_en_csv_v2_3732077/API_SP.DYN.CBRT.IN_DS2_en_csv_v2_3732077.csv',header=2)

# %%
df_Birth_rate.head(5)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                          Indicator Name  Indicator Code       1960       1961  \
# 0  Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  35.679000  34.529000
# 1  Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  47.340743  47.279733
# 2  Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  51.279000  51.373000
# 3  Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  47.119165  47.121719
# 4  Birth rate, crude (per 1,000 people)  SP.DYN.CBRT.IN  49.080000  48.779000
#
#         1962       1963       1964       1965  ...       2012       2013  \
# 0  33.320000  32.050000  30.737000  29.413000  ...  11.090000  11.111000
# 1  47.231580  47.190352  47.128506  47.058970  ...  36.770382  36.284898
# ...

# %%
df_Population.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
df_Value =  pd.DataFrame(columns=['Value'])
df_Value.head(3)
# Out:
# Empty DataFrame
# Columns: [Value]
# Index: []

# %%
df_Value['Value'] = df_Birth_rate['2019'] * df_Population['2019']

# %%
# Standardization
# df_Value['Normal']  = normalized_df=(df_Value['Value']-df_Value['Value'].mean())/df_Value['Value'].std()

# %%
# Min-Max Normalization

#df_Value['Normal'] = normalized_df=(df_Value['Value']-df_Value['Value'].min())/(df_Value['Value'].max()-df_Value['Value'].min())

# %%
df_Value['Value'].max()
# Out:
# 137436439344.08237

# %%
df_Value['Value'].sum()
# Out:
# 1594958182933.6904

# %%
idx = df_Value.loc[df_Value.isna().any(1)] # 返回有缺失的行
idx
# Out:
#      Value
# 11     NaN
# 57     NaN
# 69     NaN
# 84     NaN
# 108    NaN
# 110    NaN
# 125    NaN
# 149    NaN
# 155    NaN
# 164    NaN
# 179    NaN
# 225    NaN
# 228    NaN
# 245    NaN
# 255    NaN

# %%
for i in idx.index:
    
    try:
        print(i)
        print(df_Population.loc[i][df_Population.loc[i].last_valid_index()]*df_Birth_rate.loc[i][df_Birth_rate.loc[i].last_valid_index()])
        df_Value['Value'][i] = float(df_Population.loc[i].last_valid_index()) * float(df_Birth_rate.loc[i].last_valid_index())
        
    except:
        continue
    #df_Value['Value'][i] = float(df_Population.loc[i].last_valid_index()) * float(df_Birth_rate.loc[i].last_valid_index())
# Out:
# 11
# 916270.2000000001
# 57
# 691113.6
# 69
# 95577010.122
# 84
# 108
# 969364.8
# 110
# 125
# 670219.2
# 149
# 231539.6
# 155
# 1716626.0
# 164
# 1179918.5
# 179
# 225
# 367308.0
# 228
# 245
# 255

# %%
idx = df_Value.loc[df_Value.isna().any(1)]
idx
# Out:
#      Value
# 84     NaN
# 110    NaN
# 179    NaN
# 228    NaN
# 245    NaN
# 255    NaN

# %%
df  = pd.concat([df_Population["Country Name"],df_Population["2020"], df_Value],axis=1)

# %%
idx = df.loc[df.isna().any(1)]
idx
# Out:
#                  Country Name     2020      Value
# 69                    Eritrea      NaN  4060209.0
# 84                  Gibraltar  33691.0        NaN
# 110            Not classified      NaN        NaN
# 179                     Nauru  10834.0        NaN
# 228  Turks and Caicos Islands  38718.0        NaN
# 245                    Tuvalu  11792.0        NaN
# 255    British Virgin Islands  30237.0        NaN

# %%
#df.to_csv("res.csv")

# %%
df_Population
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# ...
